# %%
import json

file_path="/Users/gunu/Desktop/Crawling/domestic_test.json"

with open(file_path, 'r', encoding='utf-8-sig') as f:
    data=json.load(f)

# %%
for key, value in data['data'].items():
    print(key)
    print(value)
# Out:
# domesticFlights
# ...

# %%
for air in data['data']['domesticFlights']['departures']:
    airline_name = air['airlineName']  # 항공사 이름 (e.g. 대한항공)
    depart_airport = air['depCity']  # 출발 공항 코드 (e.g. GMP for 김포)
    arrival_airport = air['arrCity']  # 도착 공항 코드 (e.g. HIN for 사천)
    depart_date = air['departureDate']  # 출발 날짜 및 시간 (YYYYMMDDHHMM 형식)
    arrival_date = air['arrivalDate']  # 도착 날짜 및 시간 (YYYYMMDDHHMM 형식)
    journey_time = air['journeyTime']  # 비행 소요 시간 (HH:MM 형식)
    
    for agt_option in air['fare']:
        agt_code = agt_option['agtCode']  # 여행사 코드
        booking_class = agt_option['bookingClass']  # 예약 클래스 코드
        adult_base_fare = agt_option['adultFare']  # 성인 기본 요금
        atax = agt_option['aTax']  # 성인 공항세
        afuel = agt_option['aFuel']  # 성인 유류할증료
        child_base_fare = agt_option['childFare']  # 아동 기본 요금
        ctax = agt_option['cTax']  # 아동 공항세
        cfuel = agt_option['cFuel']  # 아동 유류할증료
        publish_free = agt_option['publishFee']  # 발권 수수료
        # etc = agt_option['etc']  # 기타 정보 (문자열)
        # supportNPay = agt_option['supportNPay']  # 네이버페이 지원 여부 (Boolean)
        discountFare = agt_option['discountFare']  # 할인 요금 (있을 경우)
    print()
# Out:
# {'agtCode': 'WEB001', 'bookingClass': 'TWR', 'adultFare': 131000, 'childFare': 126000, 'aFuel': 9900, 'cFuel': 9900, 'aTax': 4000, 'cTax': 2000, 'publishFee': 1000, 'etc': 'AL!!BizFare!!RGSPX!!R!!false!!476087!!131000(n)0', 'supportNPay': True, 'discountFare': None}
# {'agtCode': 'HAT004', 'bookingClass': 'TWR', 'adultFare': 131000, 'childFare': 126000, 'aFuel': 9900, 'cFuel': 9900, 'aTax': 4000, 'cTax': 2000, 'publishFee': 1000, 'etc': 'AL!!BizFare!!RGSPX!!R!!false!!476087!!131000(n)0', 'supportNPay': True, 'discountFare': None}
# {'agtCode': 'JJD026', 'bookingClass': 'TWR', 'adultFare': 131000, 'childFare': 0, 'aFuel': 9900, 'cFuel': 0, 'aTax': 4000, 'cTax': 0, 'publishFee': 1000, 'etc': 'AL!!BizFare!!RGSPX!!R!!false!!476087!!131000', 'supportNPay': True, 'discountFare': None}
# ...

# %%
airlineCode
KE

airlineName
대한항공

codeshare
진에어

fitName
5125

depCity
GMP

arrCity
HIN

departureCityName
김포

arrivalCityName
사천

departureDate
202408160940

arrivalDate
202408161045

dayDiff
0

departureTime
09:40

arrivalTime
10:45

detailedClass
D

seatClass
D

seatCnt
7

journeyTime
01:05

minFare
86000

supportNPay
True

fare
[{'agtCode': 'WEB001', 'bookingClass': 'KEE', 'adultFare': 70000, 'childFare': 70000, 'aFuel': 11000, 'cFuel': 11000, 'aTax': 4000, 'cTax': 2000, 'publishFee': 1000, 'etc': '0,CH00_LJ', 'supportNPay': False, 'discountFare': None}, {'agtCode': 'HAT004', 'bookingClass': 'KEE', 'adultFare': 70000, 'childFare': 70000, 'aFuel': 11000, 'cFuel': 11000, 'aTax': 4000, 'cTax': 2000, 'publishFee': 1000, 'etc': '0,CH00_LJ', 'supportNPay': False, 'discountFare': None}, {'agtCode': 'JJD026', 'bookingClass': 'KEE', 'adultFare': 70000, 'childFare': 0, 'aFuel': 11000, 'cFuel': 0, 'aTax': 4000, 'cTax': 0, 'publishFee': 1000, 'etc': 'opCode!!LJ', 'supportNPay': False, 'discountFare': None}, {'agtCode': 'MOT007', 'bookingClass': 'KEE', 'adultFare': 70000, 'childFare': 0, 'aFuel': 11000, 'cFuel': 0, 'aTax': 4000, 'cTax': 0, 'publishFee': 1000, 'etc': '', 'supportNPay': False, 'discountFare': None}, {'agtCode': 'MRT023', 'bookingClass': 'KEE', 'adultFare': 70000, 'childFare': 0, 'aFuel': 11000, 'cFuel': 0, 'aTax': 4000, 'cTax': 0, 'publishFee': 1000, 'etc': '20240815072609,V,LJ,EHDLJ', 'supportNPay': False, 'discountFare': None}, {'agtCode': 'INT005', 'bookingClass': 'KEE', 'adultFare': 70000, 'childFare': 70000, 'aFuel': 11000, 'cFuel': 11000, 'aTax': 4000, 'cTax': 2000, 'publishFee': 1000, 'etc': '', 'supportNPay': False, 'discountFare': None}, {'agtCode': 'TRP016', 'bookingClass': 'KEE', 'adultFare': 70000, 'childFare': 0, 'aFuel': 11000, 'cFuel': 0, 'aTax': 4000, 'cTax': 0, 'publishFee': 1000, 'etc': 'KE5125E,ECONOMY', 'supportNPay': False, 'discountFare': None}, {'agtCode': 'LTT017', 'bookingClass': 'KEE', 'adultFare': 70000, 'childFare': 70000, 'aFuel': 11000, 'cFuel': 11000, 'aTax': 4000, 'cTax': 2000, 'publishFee': 1000, 'etc': '4C4A', 'supportNPay': False, 'discountFare': None}, {'agtCode': 'YEL009', 'bookingClass': 'KEE', 'adultFare': 70000, 'childFare': 0, 'aFuel': 11000, 'cFuel': 0, 'aTax': 4000, 'cTax': 0, 'publishFee': 1000, 'etc': '&landingParam0=1/1/KE/20240816/0940/Y/E/EHDLJ/ADT/86000&searchId=F0C8BEFD545E4EBF8F5EAD3FAE0827E5&cabinClassCode0=Y&cacheTripType=OW', 'supportNPay': False, 'discountFare': None}, {'agtCode': 'ONT003', 'bookingClass': 'KEE', 'adultFare': 70000, 'childFare': 0, 'aFuel': 11000, 'cFuel': 0, 'aTax': 4000, 'cTax': 0, 'publishFee': 1000, 'etc': 'itin:KE/5125/KRW/70000/4000/11000/Y/E/GMP/202408160940/HIN/202408161045/7/0//LJ', 'supportNPay': False, 'discountFare': None}, {'agtCode': 'CTR013', 'bookingClass': 'KEE', 'adultFare': 72600, 'childFare': 0, 'aFuel': 0, 'cFuel': 0, 'aTax': 16000, 'cTax': 0, 'publishFee': 0, 'etc': '66bd2f00c2aeed62b7dcdc59', 'supportNPay': True, 'discountFare': None}]

--------------------
